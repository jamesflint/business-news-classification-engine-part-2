# %%
import requests

url = "https://api.skimtechnologies.com/v2/content/summary"

querystring = {"uri":"{{https://www.theguardian.com/technology/2018/mar/04/robots-screen-candidates-for-jobs-artificial-intelligence}}"}

response = requests.request("GET", url, params=querystring)

print(response.text)
# Out:
# {"message":"No API key found in request"}

# %%
import requests

url = "https://api.skimtechnologies.com/v2/content/extraction"

querystring = {"uri":"https://www.theguardian.com/technology/2018/mar/04/robots-screen-candidates-for-jobs-artificial-intelligence"}

headers = {'x-api-key': 'QvzzQtl8dstGhI1Cf9CxkIRKrsBJXi6UG7U3MnPv'}

summary_length=400

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"uri":"https:\/\/www.theguardian.com\/technology\/2018\/mar\/04\/robots-screen-candidates-for-jobs-artificial-intelligence","site_name":"www.theguardian.com","title":"How to persuade a robot that you should get the job","text":"According to Nathan Mondragon, finding the right employee is all about looking at the little things. Tens of thousands of little things, as it turns out.\nMondragon is head psychologist at HireVue, which markets software for screening job candidates. Its flagship product, used by Unilever and Goldman Sachs, asks candidates to answer interview questions in front of a camera. Meanwhile its software, like a team of hawk-eyed psychologists hiding behind a mirror, takes note of barely perceptible changes in posture, facial expression and vocal tone.\n\u201cWe break the answers people give down into many thousands of data points, into verbal and non-verbal cues,\u201d says Mondragon. \u201cIf you\u2019re answering a question about how you would spend a million doll
# ...

# %%
import pycurl

# %%
pycurl -H 'Content-Type: application/json' \ 
-X POST http://localhost:5000/api-topic -d '{"message":"Hello Data"}'
# Out:
#   File "<ipython-input-25-a572744da77d>", line 1
#     pycurl -H 'Content-Type: application/json' \
#                                              ^
# SyntaxError: invalid syntax

# %%
import requests
import json
url = 'http://localhost:5000/api-topic'
s = {"message":"Hello Data"}
s_json = json.dumps(s)
headers = {'Content-Type': 'application/json'}
r = requests.post(url, data=s_json, headers=headers)
print(r.text)
# Out:
# JSON Message: {"message": "Hello Data"}

# %%
s['message']
# Out:
# 'Hello Data'

# %%
s_json
# Out:
# '{"message": "Hello Data"}'

# %%
payload
# Out:
# {'message': 'Hello Data'}

# %%
requests.post(url, data=payload, headers=headers)
# Out:
# <Response [400]>

# %%
import requests
import json
url = 'http://localhost:5000/predict'
s = {"title":"Hotel booking app, HotelTonight, lays off 20% of its staff", "body":"HotelTonight, the app-based hotel booking service, has been forced to lay off 20% of its staff. The company was launched in 2011 to make booking last-minute accommodation easier, but faces competition from Google, which launched its own instant booking service this year, and TripAdvisor, which also has its own instant booking product. In the US, HotelTonight has consistently been rated in the top 20 travel apps on the App Store, however this still puts it behind industry giants such as Expedia, Hotels.com, Booking.com, TripAdvisor, and Kayak."}
s_json = json.dumps(s)
headers = {'Content-Type': 'application/json'}
r = requests.post(url, data=s_json, headers=headers)
print(r.text)
# Out:
# "sharingeconomy"

# %%
import requests
import json
url = 'http://localhost:5000/predict'
s = {"title":"Hotel booking app, HotelTonight, lays off 20% of its staff", "body":"HotelTonight, the app-based hotel booking service, has been forced to lay off 20% of its staff. The company was launched in 2011 to make booking last-minute accommodation easier, but faces competition from Google, which launched its own instant booking service this year, and TripAdvisor, which also has its own instant booking product. In the US, HotelTonight has consistently been rated in the top 20 travel apps on the App Store, however this still puts it behind industry giants such as Expedia, Hotels.com, Booking.com, TripAdvisor, and Kayak."}
s_json = json.dumps(s)
headers = {'Content-Type': 'application/json'}
r = requests.post(url, data=s_json, headers=headers)
print(r.text)
# Out:
# "blockchain"

# %%
# pycharm version, running on Python 2.7
        
import requests
import json
url = 'http://localhost:8080/predict'
s = {"title":"Hotel booking app, HotelTonight, lays off 20% of its staff", "body":"HotelTonight, the app-based hotel booking service, has been forced to lay off 20% of its staff. The company was launched in 2011 to make booking last-minute accommodation easier, but faces competition from Google, which launched its own instant booking service this year, and TripAdvisor, which also has its own instant booking product. In the US, HotelTonight has consistently been rated in the top 20 travel apps on the App Store, however this still puts it behind industry giants such as Expedia, Hotels.com, Booking.com, TripAdvisor, and Kayak."}
s_json = json.dumps(s)
headers = {'Content-Type': 'application/json'}
r = requests.post(url, data=s_json, headers=headers)
print(r.text)

# %%
import requests
import json
url = 'https://topic-api.appspot.com/predict'
s = {"title":"Hotel booking app, HotelTonight, lays off 20% of its staff", "body":"HotelTonight, the app-based hotel booking service, has been forced to lay off 20% of its staff. The company was launched in 2011 to make booking last-minute accommodation easier, but faces competition from Google, which launched its own instant booking service this year, and TripAdvisor, which also has its own instant booking product. In the US, HotelTonight has consistently been rated in the top 20 travel apps on the App Store, however this still puts it behind industry giants such as Expedia, Hotels.com, Booking.com, TripAdvisor, and Kayak."}
s_json = json.dumps(s)
headers = {'Content-Type': 'application/json'}
r = requests.post(url, data=s_json, headers=headers)
print(r.text)
# Out:
# <!DOCTYPE html>
# <html lang=en>
#   <meta charset=utf-8>
#   <meta name=viewport content="initial-scale=1, minimum-scale=1, width=device-width">
#   <title>Error 404 (Page not found)!!1</title>
#   <style>
# ...

# %%
#local version (virtualenv: cen3p36) 
import requests
import json
url = 'http://localhost:5000/predict'
s = {"title":"Hotel booking app, HotelTonight, lays off 20% of its staff", "body":"HotelTonight, the app-based hotel booking service, has been forced to lay off 20% of its staff. The company was launched in 2011 to make booking last-minute accommodation easier, but faces competition from Google, which launched its own instant booking service this year, and TripAdvisor, which also has its own instant booking product. In the US, HotelTonight has consistently been rated in the top 20 travel apps on the App Store, however this still puts it behind industry giants such as Expedia, Hotels.com, Booking.com, TripAdvisor, and Kayak."}
s_json = json.dumps(s)
headers = {'Content-Type': 'application/json'}
r = requests.post(url, data=s_json, headers=headers)
print(r.text)
# Out:
# "property"

# %%
# heroku version
import requests
import json
url = 'https://afternoon-shelf-15457.herokuapp.com/predict'
s = {"title":"Hotel booking app, HotelTonight, lays off 20% of its staff", "body":"HotelTonight, the app-based hotel booking service, has been forced to lay off 20% of its staff. The company was launched in 2011 to make booking last-minute accommodation easier, but faces competition from Google, which launched its own instant booking service this year, and TripAdvisor, which also has its own instant booking product. In the US, HotelTonight has consistently been rated in the top 20 travel apps on the App Store, however this still puts it behind industry giants such as Expedia, Hotels.com, Booking.com, TripAdvisor, and Kayak."}
s_json = json.dumps(s)
headers = {'Content-Type': 'application/json'}
r = requests.post(url, data=s_json, headers=headers)
print(r.text)
# Out:
# "property"
